# %% [markdown]
# # Werkcollege-opdrachten Week 1.1

# %% [markdown]
# ## Maak een virtual environment

# %% [markdown]
# Zorg dat je met behulp van de handleiding *Bouw en gebruik van virtual environments - Handleiding* een virtual environment hebt gemaakt, dat jou en je duopartner garandeert altijd dezelfde versie van geïmporteerde dependencies te gebruiken.<br>
# Voeg hier vervolgens de pandas- en de sqlite3-dependency aan toe.<br>
# Als je dit allemaal goed hebt gedaan moet de onderstaande code bij jullie allebei succesvol runnen:

# %%
import pandas as pd
import sqlite3
import warnings
warnings.simplefilter('ignore')

# %% [markdown]
# N.B.: de 2 reeds geschreven coderegels zorgen ervoor dat eventuele warnings, die code-outputs lelijker maken, uitgezet worden.

# %% [markdown]
# Zorg er daarnaast voor dat je...
# - Het bestand Waarheidstabel.png in dezelfde map als dit notebook hebt staan.
# - Het bestand Prinstabel.png in dezelfde map als dit notebook hebt staan.
# - Alle informatie onder het kopje *Basisoperaties* van de cheatsheet *Van Java naar Python - Cheatsheet* bij de hand hebt.

# %% [markdown]
# ## Output, variabelen en input

# %% [markdown]
# Geef code waarmee het volgende op het scherm komt te staan:<br>
# geef me je geld <br>
# of ik gebruik geweld, <br>
# toen kwam de controle aangesneld

# %%
print("geef me je geld")
print("of ik gebruik geweld,")
print("toen kwam de controle aangesneld")
# Out:
# geef me je geld
# of ik gebruik geweld,
# toen kwam de controle aangesneld

# %% [markdown]
# Declareer 2 variabelen zodat de volgende tekst geprint wordt:<br>
# Apenhoofd<br>
# Paardenstaart

# %%
String1 = "Apenhoofd"
String2 = "Paardenstaart"

print(String1)
print(String2)
# Out:
# Apenhoofd
# Paardenstaart

# %% [markdown]
# Voeg code toe zodat het programma het volgende doet:<br>
# 1): Op het scherm komt A, B, C, D, ..., F, G te staan<br>
# 2): De gebruiker voert een letter in<br>
# 3): Op het scherm komt te staan:<br>
# Het is inderdaad:<br>
# *ingevoerde letter*

# %%
letter = input("Voer de missende letter in: A, B, C, D, ..., F, G")
if letter == "E":
    print(f"Het is inderdaad {letter}!")
else:
    print("Helaas, dat is niet correct. Probeer het nog eens.")
# Out:
# Het is inderdaad E!

# %% [markdown]
# ## Stringconcatenatie en Rekenen

# %% [markdown]
# Schrijf code dat een inkomen inleest en het volgende uitprint:<br>
# Uw inkomen (*ingelezen inkomen*) is zeer acceptabel.

# %%
inkomen = input("Wat is uw inkomen?")
print(f"Uw inkomen {inkomen} euro per jaar is zeer acceptabel.")
# Out:
# Uw inkomen 10000 euro per jaar is zeer acceptabel.

# %% [markdown]
# De oppervlakte van een driehoek is 1/2 * hoogte * basis<br>
# Schrijf code zodat het programma het volgende doet:<br>
# 1): Op het scherm komt Wat is de basis? te staan<br>
# 2): De gebruiker voert een basis in<br>
# 3): Op het scherm komt Wat is de hoogte? te staan<br>
# 4): De gebruiker voert een hoogte in<br>
# 5): Op het scherm komt: De oppervlakte van de driehoek is *berekende oppervlakte* te staan

# %%
driehoek_basis = input("Wat is de basis van de driehoek?")
driehoek_hoogte = input("Wat is de hoogte van de driehoek?")
driehoek_oppervlakte = 0.5 * float(driehoek_basis) * float(driehoek_hoogte)
print(f"De oppervlakte van de driehoek is {driehoek_oppervlakte} vierkante eenheden.")
# Out:
# De oppervlakte van de driehoek is 1800.0 vierkante eenheden.

# %% [markdown]
# ## if() en booleans

# %% [markdown]
# Schrijf code dat het volgende doet:<br>
# 1): De gebruiker voert in hoe oud iemand is<br>
# 2): De gebruiker voert in of de ouders meegekomen zijn (input is J of N)<br><br>
#
# Als...
# - Jonger dan 6, wel ouders: op het scherm staat Je mag het zwembad in
# - Jonger dan 6, geen ouders: op het scherm staat Je mag het niet zwembad in
# - Leeftijd vanaf 6, geen ouders: op het scherm staat Je mag het zwembad in als je een diploma hebt
# - Leeftijd vanaf 6, wel ouders: op het scherm staat Waarom neem je nog je ouders mee?

# %%
age = int(input("Voer je leeftijd in: "))
ouders = input("Ouders meegkomen? (ja/nee): ")
if age < 6 and ouders == "ja":
    print("Je mag het zwembad in")
elif age < 6 and ouders == "nee":
    print("Je mag het zwembad niet in")
elif age >= 6 and ouders == "nee":
    print("Je mag het zwembad in als je een diploma hebt")
elif age >= 6 and ouders == "ja":
    print("Waarom neem je nog steeds je ouders mee?")
# Out:
# Waarom neem je nog steeds je ouders mee?

# %% [markdown]
# Schrijf code zodat de boolean-variabelen een en twee aangemaakt worden en waarmee de juiste waarde in de boolean-variabele uitkomst komt te staan. In de waarheidstabel hieronder staat wat de waarde van uitkomst is bij de verschillende mogelijke combinaties van een en twee.<br><br>
# <img src="Waarheidstabel.png">

# %%
een = True
twee = False

uitkomst = not (een and not twee)

print(uitkomst)
# Out:
# False

# %% [markdown]
# ## Functies

# %% [markdown]
# Schrijf een methode wachtwoord die als parameters twee woorden meekrijgt en het volgende controleert:
# - Als de woorden gelijk zijn, print het programma gelijk.
# - Als de woorden ongelijk zijn print het programma ongelijk.
#
# Vergeet niet dat je de methode niet alleen aan moet maken, maar ook aan moet roepen om output te krijgen.

# %%
def wachtwoord(woord1, woord2):
    if woord1 == woord2:
        print("gelijk")
    else:
        print("ongelijk")

wachtwoord("endurance", "endurance")
wachtwoord("endurance", "formula")
# Out:
# gelijk
# ongelijk

# %% [markdown]
# Schrijf de methode zoekPrins die als parameter een prinses meekrijgt en vervolgens de bijbehorende prins oplevert, volgens de volgende tabel:<br><br>
# <img src="Prinstabel.png"><br>
# Als de naam van de prinses niet in de tabel staat wordt het volgende door de methode teruggegeven: naamloos.<br>
# Roep ten slotte de gemaakte methode ook daadwerkelijk aan met een zelfgekozen prinsessennaam.

# %%
def zoekPrins(prinses):
    koppels = {
        "Aurora": "Philip",
        "Ariël": "Eric",
        "Jasmine": "Aladdin",
        "Pocahontas": "John",
        "Belle": "Beast",
        "Tiana": "Naveen",
        "Mulan": "Shang"
    }
    
    return koppels.get(prinses, "naamloos")

print(zoekPrins("Belle"))
print(zoekPrins("Maxima"))
# Out:
# Beast
# naamloos

# %% [markdown]
# ## While-loop

# %% [markdown]
# Schrijf de inhoud van de methode wachtwoord. Deze heeft geen parameters en laat de gebruiker twee wachtwoorden invoeren, waarna hij bekijkt of deze gelijk zijn. Zolang dat niet het geval is wordt er eerst Fout, probeer het opnieuw! uitgeprint en moet de gebruiker het opnieuw proberen.<br>Als de gebruiker het goed doet, komt er Succes! op het scherm te staan.

# %%
def wachtwoord():
    while True:
        wachtwoord1 = input("Voer een wachtwoord in: ")
        wachtwoord2 = input("Voer het wachtwoord opnieuw in: ")
        
        if wachtwoord1 == wachtwoord2:
            print("Succes!")
            break
        else:
            print("Fout, probeer het opnieuw!")

wachtwoord()
# Out:
# Fout, probeer het opnieuw!
# Fout, probeer het opnieuw!
# Fout, probeer het opnieuw!
# Fout, probeer het opnieuw!
# Fout, probeer het opnieuw!
# Fout, probeer het opnieuw!
# Fout, probeer het opnieuw!
# Succes!

# %% [markdown]
# Schrijf de inhoud van de methode tafels. De methode print alle tafels vanaf 1 (dus inclusief de tafel van 1) tot en met de tafel van het meegekregen getal (dus inclusief de tafel van getal).  Zet een witregel tussen alle tafels in. <br>
# Let op:
# - Gebruik een while-loop
# - Gebruik de reeds geschreven methode tafel om een tafel uit te printen

# %%
def tafel(getal: int):
    teller: int = 1

    while(teller <= 10):
        print(f'{teller} x {getal} = {teller * getal}')
        teller += 1

def tafels(getal: int):
    i = 1
    while i <= getal:
        tafel(i)
        print()
        i += 1

x: int = int(input())
tafels(x)
# Out:
# 1 x 1 = 1
# 2 x 1 = 2
# 3 x 1 = 3
# 4 x 1 = 4
# 5 x 1 = 5
# 6 x 1 = 6
# 7 x 1 = 7
# 8 x 1 = 8
# 9 x 1 = 9
# 10 x 1 = 10
#
# 1 x 2 = 2
# 2 x 2 = 4
# 3 x 2 = 6
# 4 x 2 = 8
# 5 x 2 = 10
# 6 x 2 = 12
# 7 x 2 = 14
# 8 x 2 = 16
# 9 x 2 = 18
# 10 x 2 = 20
#
# 1 x 3 = 3
# 2 x 3 = 6
# 3 x 3 = 9
# 4 x 3 = 12
# 5 x 3 = 15
# 6 x 3 = 18
# 7 x 3 = 21
# 8 x 3 = 24
# 9 x 3 = 27
# 10 x 3 = 30
#
# 1 x 4 = 4
# 2 x 4 = 8
# 3 x 4 = 12
# 4 x 4 = 16
# 5 x 4 = 20
# 6 x 4 = 24
# 7 x 4 = 28
# 8 x 4 = 32
# 9 x 4 = 36
# 10 x 4 = 40

# %% [markdown]
# ## For-loop

# %% [markdown]
# Vervang de while-loop door een werkende for-loop. De uitkomst van het programma mag daarbij niet veranderen.

# %%
def loopje():
    for aantal in range(0, 11):
        print(f"huidige getal: {aantal}")

loopje()
# Out:
# huidige getal: 0
# huidige getal: 1
# huidige getal: 2
# huidige getal: 3
# huidige getal: 4
# huidige getal: 5
# huidige getal: 6
# huidige getal: 7
# huidige getal: 8
# huidige getal: 9
# huidige getal: 10

# %% [markdown]
# Schrijf de methode checkEven die achtereenvolgens 12 getallen inleest en afdrukt hoe vaak het ingevoerde getal even was.

# %%
def checkEven():
    teller = 0
    i = 0

    while i < 12:
        getal = int(input("Voer een getal in: "))
        
        if getal % 2 == 0:
            teller += 1
        
        i += 1

    print(f"Aantal even getallen: {teller}")

checkEven()
# Out:
# Aantal even getallen: 5

# %% [markdown]
# ## Objectoriëntatie

# %% [markdown]
# Maak een minisysteem voor een kledingwinkel. Maak verschillende klassen voor verschillende soorten kledingstukken, waarbij sommige klassen geërfd worden van andere klassen.
# - Maak een klasse Kledingstuk aan, waarin door de constructor een merk, een maat en een prijs geïnitialiseerd worden.
# - Maak een klasse Broek en een klasse Shirt, beide erven van de klasse Kledingstuk. Voeg aan Broek een broek_type, en aan Shirt een shirt_type toe (d.m.v. constructorgebruik).
# - Maak een klasse Spijkerbroek die erft van broek en een klasse Poloshirt die erft van shirt. Voeg aan Spijkerbroek een blauwtint toe, en aan Poloshirt een kraagsoort (d.m.v. constructorgebruik).
# - Implementeer in elke klasse een beschrijvingmethode, waarmee alle informatie over het betreffende kledingstuk wordt afgedrukt.
# - Maak van elke klasse een object aan en roep de beschrijvingmethode aan. Controleer nauwkeurig of alles naar behoren werkt.

# %%
class Kledingstuk:
    def __init__(self, merk, maat, prijs):
        self.merk = merk
        self.maat = maat
        self.prijs = prijs

    def beschrijving(self):
        print(f"Merk: {self.merk}, Maat: {self.maat}, Prijs: €{self.prijs}")

class Broek(Kledingstuk):
    def __init__(self, merk, maat, prijs, broek_type):
        super().__init__(merk, maat, prijs)
        self.broek_type = broek_type

    def beschrijving(self):
        super().beschrijving()
        print(f"Broek type: {self.broek_type}")

class Shirt(Kledingstuk):
    def __init__(self, merk, maat, prijs, shirt_type):
        super().__init__(merk, maat, prijs)
        self.shirt_type = shirt_type

    def beschrijving(self):
        super().beschrijving()
        print(f"Shirt type: {self.shirt_type}")

class Spijkerbroek(Broek):
    def __init__(self, merk, maat, prijs, broek_type, blauwtint):
        super().__init__(merk, maat, prijs, broek_type)
        self.blauwtint = blauwtint

    def beschrijving(self):
        super().beschrijving()
        print(f"Blauwtint: {self.blauwtint}")

class Poloshirt(Shirt):
    def __init__(self, merk, maat, prijs, shirt_type, kraagsoort):
        super().__init__(merk, maat, prijs, shirt_type)
        self.kraagsoort = kraagsoort

    def beschrijving(self):
        super().beschrijving()
        print(f"Kraagsoort: {self.kraagsoort}")

# Objecten aanmaken en beschrijvingen tonen
if __name__ == "__main__":
    kledingstuk = Kledingstuk("Generic", "M", 20.0)
    broek = Broek("Levi's", "L", 50.0, "Cargo")
    shirt = Shirt("Nike", "S", 30.0, "T-shirt")
    spijkerbroek = Spijkerbroek("Wrangler", "XL", 70.0, "Slim fit", "Donkerblauw")
    poloshirt = Poloshirt("Ralph Lauren", "M", 40.0, "Polo", "Kraagloos")

    print("Kledingstuk:")
    kledingstuk.beschrijving()
    print()

    print("Broek:")
    broek.beschrijving()
    print()

    print("Shirt:")
    shirt.beschrijving()
    print()

    print("Spijkerbroek:")
    spijkerbroek.beschrijving()
    print()

    print("Poloshirt:")
    poloshirt.beschrijving()
# Out:
# Kledingstuk:
# Merk: Generic, Maat: M, Prijs: €20.0
#
# Broek:
# Merk: Levi's, Maat: L, Prijs: €50.0
# Broek type: Cargo
#
# Shirt:
# Merk: Nike, Maat: S, Prijs: €30.0
# Shirt type: T-shirt
#
# Spijkerbroek:
# Merk: Wrangler, Maat: XL, Prijs: €70.0
# Broek type: Slim fit
# Blauwtint: Donkerblauw
#
# Poloshirt:
# Merk: Ralph Lauren, Maat: M, Prijs: €40.0
# Shirt type: Polo
# Kraagsoort: Kraagloos

# %% [markdown]
# ## Verzamelingen

# %% [markdown]
# Kijk nu naar alle info onder het kopje *Verzamelingen* van de cheatsheet *Van Java naar Python - Cheatsheet*.

# %% [markdown]
# Initialiseer een lijst met de naam mijn_lijst met de volgende waarden:<br>
# Jelle, Marleen, Henk, Fatima, Jelle, Henk

# %%
mijn_lijst = ["Jelle", "Marleen", "Henk", "Fatima", "Jelle", "Henk"]
print (mijn_lijst)
# Out:
# ['Jelle', 'Marleen', 'Henk', 'Fatima', 'Jelle', 'Henk']

# %% [markdown]
# Probeer nu de eerste waarde uit te lijst te veranderen in een naam naar keuze. Lukt dat?

# %%
mijn_lijst[0] = "Abhishek"
print(mijn_lijst)
# Out:
# ['Abhishek', 'Marleen', 'Henk', 'Fatima', 'Jelle', 'Henk']

# %% [markdown]
# Maak van bovengenoemde lijst nu een tupel, genaamd: mijn_tupel.

# %%
mijn_tupel = tuple(mijn_lijst)
print(mijn_tupel)
# Out:
# ('Jelle', 'Marleen', 'Henk', 'Fatima', 'Jelle', 'Henk')

# %% [markdown]
# Probeer nu de laatste waarde uit te tupel te veranderen in een naam naar keuze. Lukt dat?

# %%
mijn_tupel[5] = "Akshay"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 mijn_tupel[5] = "Akshay"
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# Initialiseer een dictionary met de volgende key-value-combinaties:
# - naam: "Jelle"
# - leeftijd: 30
# - beroep: "Docent"
# - hobby: "Volleybal"

# %%
mijn_dict = {
    "naam": "Jelle",
    "leeftijd": 30,
    "beroep": "Docent",
    "hobby": "Volleybal"
}
print(mijn_dict)
# Out:
# {'naam': 'Jelle', 'leeftijd': 30, 'beroep': 'Docent', 'hobby': 'Volleybal'}

# %% [markdown]
# Probeer nu de naam te veranderen naar een naam naar keuze. Lukt dat?

# %%
mijn_dict["naam"] = "Greninja"
print(mijn_dict)
# Out:
# {'naam': 'Greninja', 'leeftijd': 30, 'beroep': 'Docent', 'hobby': 'Volleybal'}

# %% [markdown]
# ## Data klaarzetten

# %% [markdown]
# Zet de volgende bestanden in een makkelijk terug te vinden map:
# - go_sales.sqlite
# - go_crm.sqlite
# - go_staff.sqlite

# %% [markdown]
# Bestudeer de bovenste 3 bestanden met DB Browser (SQLite) dat <a href="https://sqlitebrowser.org/dl/">hier</a> te downloaden is. Wat valt je op qua datatypen?<br>

# %% [markdown]
# ## Databasetabel inlezen

# %% [markdown]
# Creëer een databaseconnectie met het bestand go_sales.sqlite. Let op: deze staat in de map "data", die op zijn beurt in de hoofdmap staat. Tip: met `"../"` in `connect()` kun je naar de bovenliggende map gaan.

# %%
import sqlite3
salesConn = sqlite3.connect('go_sales.sqlite')

# %% [markdown]
# <b>Let goed op:</b><br>
# Als je per ongeluk een verkeerde bestandsnaam ingeeft, maakt Python zélf een leeg databasebestand aan! Er ontstaat dan dus een nieuwe .sqlite, en dat is nadrukkelijk <u>niet de bedoeling.</u>

# %% [markdown]
# Gebruik de onderstaande sql_query om te achterhalen welke databasetabellen in go_sales zitten.

# %%
sql_query = "SELECT name FROM sqlite_master WHERE type='table';"

#Vul dit codeblok verder in

print(salesConn.execute(sql_query).fetchall())
# Out:
# [('country',), ('order_details',), ('order_header',), ('order_method',), ('product',), ('product_line',), ('product_type',), ('retailer_site',), ('return_reason',), ('returned_item',), ('sales_branch',), ('sales_staff',)]

# %% [markdown]
# Krijg je lege output? Dan heb je per ongeluk een leeg  databasebestand (.sqlite) aangemaakt.<br>
# Lees de informatie onder het kopje <b>Let goed op:</b> hierboven nog eens goed door.

# %% [markdown]
# Gebruik de gecreëerde databaseconnectie om de resultaten van de volgende query in een DataFrame te zetten:<br>
# *SELECT * FROM sales_staff*

# %%
import pandas as pd
sales_staff = pd.read_sql("SELECT * FROM sales_staff", salesConn)
sales_staff
# Out:
#      SALES_STAFF_CODE FIRST_NAME  LAST_NAME                   POSITION_EN  \
# 0                   4      Denis       Pagé                Branch Manager
# 1                   5  Élizabeth     Michel  Level 3 Sales Representative
# 2                   6      Émile   Clermont  Level 1 Sales Representative
# 3                   7    Étienne     Jauvin  Level 2 Sales Representative
# 4                  12    Elsbeth  Wiesinger  Level 2 Sales Representative
# ..                ...        ...        ...                           ...
# 97                120      Giele   Laermans  Level 1 Sales Representative
# 98                121   François    De Crée  Level 1 Sales Representative
# 99                122     Yvette    Lattrez  Level 3 Sales Representative
# 100               123      Willi  Seefelder  Level 2 Sales Representative
# 101               124     Sabine     Grüner  Level 3 Sales Representative
#
#             WORK_PHONE  EXTENSION                FAX                   EMAIL  \
# 0    +33 1 68 94 52 20      325.0  +33 1 68 94 56 60       DPage@grtd123.com
# 1    +33 1 68 94 52 20      336.0  +33 1 68 94 56 60     EMichel@grtd123.com
# 2    +33 1 68 94 52 20      378.0  +33 1 68 94 56 60   EClermont@grtd123.com
# 3    +33 1 68 94 52 20      398.0  +33 1 68 94 56 60     EJauvin@grtd123.com
# 4    +(49) 40 663 1990     1818.0  +(49) 40 663 4571  EWiesinger@grtd123.com
# ..                 ...        ...                ...                     ...
# 97     +32 16 20.73.21     1340.0    +32 16 20.73.32   GLaermans@grtd123.com
# 98     +32 16 20.73.21     1642.0    +32 16 20.73.32     FDecree@grtd123.com
# 99     +32 16 20.73.21     1633.0    +32 16 20.73.32    YLattrez@grtd123.com
# 100  +(43) 13 79 56 32      325.0  +(43) 13 79 56 33  WSeefelder@grtd123.com
# 101  +(43) 13 79 56 32      348.0  +(43) 13 79 56 33     SGruner@grtd123.com
#
#      DATE_HIRED  SALES_BRANCH_CODE
# 0    1996-11-03                  6
# 1    1995-06-08                  6
# 2    1998-04-07                  6
# 3    1997-08-16                  6
# 4    1997-02-27                 13
# ..          ...                ...
# 97   1999-11-15                 38
# 98   1999-12-01                 38
# 99   1999-12-09                 38
# 100  1998-10-28                 39
# 101  1998-02-18                 39
#
# [102 rows x 10 columns]

# %% [markdown]
# ## Datumkolommen afhandelen

# %% [markdown]
# Zoals je misschien al hebt gezien in DB Browser, zijn datums als TEXT opgeslagen, en niet als DATE, DATETIME o.i.d. Hier moeten we dus nog even "typische datumkolommen" van maken. Dat doen we met de volgende code:

# %%
sales_staff['DATE_HIRED'] = pd.to_datetime(sales_staff['DATE_HIRED'])
sales_staff.dtypes
# Out:
# SALES_STAFF_CODE              int64
# FIRST_NAME                      str
# LAST_NAME                       str
# POSITION_EN                     str
# WORK_PHONE                      str
# EXTENSION                   float64
# FAX                             str
# EMAIL                           str
# DATE_HIRED           datetime64[us]
# SALES_BRANCH_CODE             int64
# dtype: object

# %% [markdown]
# Als we hier het jaar uit willen halen, schrijven we:

# %%
pd.DatetimeIndex(sales_staff['DATE_HIRED']).year
# Out:
# Index([1996, 1995, 1998, 1997, 1997, 1999, 1997, 1998, 1996, 1996,
#        ...
#        1998, 2000, 1999, 2000, 1999, 1999, 1999, 1999, 1998, 1998],
#       dtype='int32', name='DATE_HIRED', length=102)

# %% [markdown]
# Deze zelfde syntax is te gebruiken voor het extraheren van kwartalen, maanden, weken en dagen. Probeer het maar eens!

# %% [markdown]
# ## DataFrames uitsplitsen en opbouwen met Series

# %% [markdown]
# De volgende 5 kolommen hebben betrekking op de contactdetails van elke medewerker in dit DataFrame:
# - SALES_STAFF_CODE
# - WORK_PHONE
# - EXTENSION
# - FAX
# - EMAIL
#
# Maak van elk van deze 5 kolommen een serie.

# %%
sales_staff_code = sales_staff['SALES_STAFF_CODE']
work_phone = sales_staff['WORK_PHONE']
extension = sales_staff['EXTENSION']
fax = sales_staff['FAX']
email = sales_staff['EMAIL']

print("SALES_STAFF_CODE series:")
print(sales_staff_code.head())
# Out:
# SALES_STAFF_CODE series:
# 0     4
# 1     5
# 2     6
# 3     7
# 4    12
# Name: SALES_STAFF_CODE, dtype: int64

# %% [markdown]
# Zet allevijf gecreëerde series als kolommen naast elkaar in een DataFrame (*contact_details*). Gebruik pd.concat(...)<br>
# Hulpvraag: welke waarde geef je aan de axis-parameter?

# %%
contact_details = pd.concat([sales_staff_code, work_phone, extension, fax, email], axis=1)

print(f"Shape van contact_details: {contact_details.shape}")
print(f"\nKolommen: {list(contact_details.columns)}")
print(f"\nEerste 5 rijen van contact_details:")
print(contact_details.head())
# Out:
# Shape van contact_details: (102, 5)
#
# Kolommen: ['SALES_STAFF_CODE', 'WORK_PHONE', 'EXTENSION', 'FAX', 'EMAIL']
#
# Eerste 5 rijen van contact_details:
#    SALES_STAFF_CODE         WORK_PHONE  EXTENSION                FAX  \
# 0                 4  +33 1 68 94 52 20      325.0  +33 1 68 94 56 60
# 1                 5  +33 1 68 94 52 20      336.0  +33 1 68 94 56 60
# 2                 6  +33 1 68 94 52 20      378.0  +33 1 68 94 56 60
# 3                 7  +33 1 68 94 52 20      398.0  +33 1 68 94 56 60
# 4                12  +(49) 40 663 1990     1818.0  +(49) 40 663 4571
#
#                     EMAIL
# 0       DPage@grtd123.com
# 1     EMichel@grtd123.com
# 2   EClermont@grtd123.com
# 3     EJauvin@grtd123.com
# 4  EWiesinger@grtd123.com

# %% [markdown]
# ## Series en DataFrames maken vanuit lists en dictionaries

# %% [markdown]
# Met .head(*getal*) kan je de bovenste *getal* rijen van een tabel selecteren.<br>
# Selecteer op deze manier de bovenste 5 rijen van *contact_details*.<br>
# Sla dit resultaat op in een nieuw DataFrame.

# %%
# Selecteer de bovenste 5 rijen van contact_details en sla op in een nieuw DataFrame
top_5_contact_details = contact_details.head(5)

print("Bovenste 5 rijen van contact_details:")
print(top_5_contact_details)
print(f"\nShape: {top_5_contact_details.shape}")
# Out:
# Bovenste 5 rijen van contact_details:
#    SALES_STAFF_CODE         WORK_PHONE  EXTENSION                FAX  \
# 0                 4  +33 1 68 94 52 20      325.0  +33 1 68 94 56 60
# 1                 5  +33 1 68 94 52 20      336.0  +33 1 68 94 56 60
# 2                 6  +33 1 68 94 52 20      378.0  +33 1 68 94 56 60
# 3                 7  +33 1 68 94 52 20      398.0  +33 1 68 94 56 60
# 4                12  +(49) 40 663 1990     1818.0  +(49) 40 663 4571
#
#                     EMAIL
# 0       DPage@grtd123.com
# 1     EMichel@grtd123.com
# 2   EClermont@grtd123.com
# 3     EJauvin@grtd123.com
# 4  EWiesinger@grtd123.com
#
# Shape: (5, 5)

# %% [markdown]
# Aan deze 10 rijen met contactdetails willen we 3 kolommen toevoegen: 'FIRST_LANGUAGE', 'SECOND_LANGUAGE' & 'THIRD_LANGUAGE'.<br>
# Iedereens 'First Language' is Engels, afgekort 'EN'. Maak een lijst waarin 5x 'EN' staat.<br>
# Converteer deze lijst vervolgens naar een serie en voeg deze horizontaal samen met het resultaat van de vorige opdracht.<br>
# Vergeet niet een passende naam te geven aan de nieuw ontstane kolom.

# %%
# Maak een lijst met 5x 'EN' (First Language = Engels)
first_language_list = ['EN'] * 5

# Converteer de lijst naar een pandas Serie
first_language_series = pd.Series(first_language_list, name='FIRST_LANGUAGE')

# Voeg de serie horizontaal toe aan top_5_contact_details
top_5_contact_details = pd.concat([top_5_contact_details, first_language_series], axis=1)

print("DataFrame met FIRST_LANGUAGE kolom toegevoegd:")
print(top_5_contact_details)
print(f"\nShape: {top_5_contact_details.shape}")
print(f"Kolommen: {list(top_5_contact_details.columns)}")
# Out:
# DataFrame met FIRST_LANGUAGE kolom toegevoegd:
#    SALES_STAFF_CODE         WORK_PHONE  EXTENSION                FAX  \
# 0                 4  +33 1 68 94 52 20      325.0  +33 1 68 94 56 60
# 1                 5  +33 1 68 94 52 20      336.0  +33 1 68 94 56 60
# 2                 6  +33 1 68 94 52 20      378.0  +33 1 68 94 56 60
# 3                 7  +33 1 68 94 52 20      398.0  +33 1 68 94 56 60
# 4                12  +(49) 40 663 1990     1818.0  +(49) 40 663 4571
#
#                     EMAIL FIRST_LANGUAGE
# 0       DPage@grtd123.com             EN
# 1     EMichel@grtd123.com             EN
# 2   EClermont@grtd123.com             EN
# 3     EJauvin@grtd123.com             EN
# 4  EWiesinger@grtd123.com             EN
#
# Shape: (5, 6)
# Kolommen: ['SALES_STAFF_CODE', 'WORK_PHONE', 'EXTENSION', 'FAX', 'EMAIL', 'FIRST_LANGUAGE']

# %% [markdown]
# Maak nu de tweede kolom ('SECOND_LANGUAGE'). Maak daarvoor een dictionary, met daarin...
# - Als keys: alle indexen uit het resultaat van het vorige codeblok.
# - Als values: bij de eerste 3 elementen 'FR' (Frankrijk), bij de laatste 2 'DE' (Duitsland).
#
# Maak vervolgens ook hier weer een serie van en voeg ook deze weer horizontaal samen met het rsultaat van de vorige opdracht.<br>
# Vergeet niet een passende naam te geven aan de nieuw ontstane kolom.

# %%
# Maak een dictionary met indices als keys en taalcodes als values
# Eerste 3 elementen: 'FR' (Frankrijk), laatste 2: 'DE' (Duitsland)
second_language_dict = {
    0: 'FR',
    1: 'FR',
    2: 'FR',
    3: 'DE',
    4: 'DE'
}

# Converteer de dictionary naar een pandas Serie
second_language_series = pd.Series(second_language_dict, name='SECOND_LANGUAGE')

# Voeg de serie horizontaal toe aan top_5_contact_details
top_5_contact_details = pd.concat([top_5_contact_details, second_language_series], axis=1)

print("DataFrame met SECOND_LANGUAGE kolom toegevoegd:")
print(top_5_contact_details)
print(f"\nShape: {top_5_contact_details.shape}")
print(f"Kolommen: {list(top_5_contact_details.columns)}")
# Out:
# DataFrame met SECOND_LANGUAGE kolom toegevoegd:
#    SALES_STAFF_CODE         WORK_PHONE  EXTENSION                FAX  \
# 0                 4  +33 1 68 94 52 20      325.0  +33 1 68 94 56 60
# 1                 5  +33 1 68 94 52 20      336.0  +33 1 68 94 56 60
# 2                 6  +33 1 68 94 52 20      378.0  +33 1 68 94 56 60
# 3                 7  +33 1 68 94 52 20      398.0  +33 1 68 94 56 60
# 4                12  +(49) 40 663 1990     1818.0  +(49) 40 663 4571
#
#                     EMAIL FIRST_LANGUAGE SECOND_LANGUAGE
# 0       DPage@grtd123.com             EN              FR
# 1     EMichel@grtd123.com             EN              FR
# 2   EClermont@grtd123.com             EN              FR
# 3     EJauvin@grtd123.com             EN              DE
# 4  EWiesinger@grtd123.com             EN              DE
#
# Shape: (5, 7)
# Kolommen: ['SALES_STAFF_CODE', 'WORK_PHONE', 'EXTENSION', 'FAX', 'EMAIL', 'FIRST_LANGUAGE', 'SECOND_LANGUAGE']

# %% [markdown]
# Maak ten slotte de derde kolom ('THIRD_LANGUAGE') door een dictionary te maken met daarin...
# - Als key: de naam van de nieuwe kolom. Zie je het verschil qua keys met de vorige opdracht?
# - Als waarde: een lijst met daarin 'NL', 'NL', 'JPN', 'JPN', 'KOR'.
#
# Converteer deze dictionary nu naar een DataFrame en voeg deze horizontaal samen met het resultaat van de vorige opdracht.<br>
# Waarom hoef je hierna de nieuw ontstane kolom geen passende naam meer te geven?

# %%
# Maak een dictionary met als key de naam van de kolom en als waarde een lijst met taalcodes
third_language_dict = {
    'THIRD_LANGUAGE': ['NL', 'NL', 'JPN', 'JPN', 'KOR']
}

# Converteer de dictionary naar een DataFrame (niet naar een Serie!)
third_language_df = pd.DataFrame(third_language_dict)

# Voeg het DataFrame horizontaal toe aan top_5_contact_details
top_5_contact_details = pd.concat([top_5_contact_details, third_language_df], axis=1)

print("DataFrame met THIRD_LANGUAGE kolom toegevoegd:")
print(top_5_contact_details)
print(f"\nShape: {top_5_contact_details.shape}")
print(f"Kolommen: {list(top_5_contact_details.columns)}")

# Uitleg over de verschilappel in keys:
print("\n--- Verschil in dictionary keys ---")
print("FIRST_LANGUAGE - keys waren indices: 0, 1, 2, 3, 4 (geconverteerd naar Serie met name=)")
print("SECOND_LANGUAGE - keys waren indices: 0, 1, 2, 3, 4 (geconverteerd naar Serie met name=)")
print("THIRD_LANGUAGE - key is de kolom naam: 'THIRD_LANGUAGE' (automatisch column name als DataFrame)")
print("\nDaarom hoeven we hierna geen passende naam meer te geven aan de kolom!")
# Out:
# DataFrame met THIRD_LANGUAGE kolom toegevoegd:
#    SALES_STAFF_CODE         WORK_PHONE  EXTENSION                FAX  \
# 0                 4  +33 1 68 94 52 20      325.0  +33 1 68 94 56 60
# 1                 5  +33 1 68 94 52 20      336.0  +33 1 68 94 56 60
# 2                 6  +33 1 68 94 52 20      378.0  +33 1 68 94 56 60
# 3                 7  +33 1 68 94 52 20      398.0  +33 1 68 94 56 60
# 4                12  +(49) 40 663 1990     1818.0  +(49) 40 663 4571
#
#                     EMAIL FIRST_LANGUAGE SECOND_LANGUAGE THIRD_LANGUAGE
# 0       DPage@grtd123.com             EN              FR             NL
# 1     EMichel@grtd123.com             EN              FR             NL
# 2   EClermont@grtd123.com             EN              FR            JPN
# 3     EJauvin@grtd123.com             EN              DE            JPN
# 4  EWiesinger@grtd123.com             EN              DE            KOR
#
# Shape: (5, 8)
# Kolommen: ['SALES_STAFF_CODE', 'WORK_PHONE', 'EXTENSION', 'FAX', 'EMAIL', 'FIRST_LANGUAGE', 'SECOND_LANGUAGE', 'THIRD_LANGUAGE']
#
# --- Verschil in dictionary keys ---
# FIRST_LANGUAGE - keys waren indices: 0, 1, 2, 3, 4 (geconverteerd naar Serie met name=)
# SECOND_LANGUAGE - keys waren indices: 0, 1, 2, 3, 4 (geconverteerd naar Serie met name=)
# THIRD_LANGUAGE - key is de kolom naam: 'THIRD_LANGUAGE' (automatisch column name als DataFrame)
#
# Daarom hoeven we hierna geen passende naam meer te geven aan de kolom!

# %% [markdown]
# ## Data toevoegen

# %% [markdown]
# ### Rijen

# %% [markdown]
# Gebruik de originele databasetabel *sales_staff*.<br>
# Voeg een extra rij toe met eigen invulling. Zorg ervoor dat de index netjes doorloopt.<br>
# Hulpvraag: welke waarde geef je nu aan axis?

# %%
# Voeg een extra rij toe aan sales_staff met eigen invulling
# Zorg ervoor dat de index netjes doorloopt

# Maak een dictionary voor de nieuwe rij met eigen data
new_row = {
    'SALES_STAFF_CODE': 103,
    'FIRST_NAME': 'Parag',
    'LAST_NAME': 'Student',
    'POSITION_EN': 'Data Analyst Intern',
    'WORK_PHONE': '+31-123-456-7890',
    'EXTENSION': 123,
    'FAX': '+31-123-456-7891',
    'EMAIL': 'parag.student@hhs.nl',
    'DATE_HIRED': '2024-03-24',
    'SALES_BRANCH_CODE': 1,
    'TRIAL888': None
}

# Converteer de dictionary naar een DataFrame
new_df = pd.DataFrame([new_row])

# Voeg de nieuwe rij toe aan sales_staff met axis=0 (verticale concatenatie)
sales_staff = pd.concat([sales_staff, new_df], axis=0, ignore_index=True)

# Controleer de laatste rijen om te zien dat de index doorloopt
print("Laatste 3 rijen van sales_staff na toevoeging:")
print(sales_staff.tail(3))
print(f"\nNieuwe shape: {sales_staff.shape}")
print(f"Index van laatste rij: {sales_staff.index[-1]}")

# Antwoord op hulpvraag: welke waarde geef je nu aan axis?
print("\nHulpvraag: welke waarde geef je nu aan axis?")
print("Antwoord: axis=0, omdat we een rij (verticaal) toevoegen aan het DataFrame.")
# Out:
# Laatste 3 rijen van sales_staff na toevoeging:
#      SALES_STAFF_CODE FIRST_NAME LAST_NAME                   POSITION_EN  \
# 101               124     Sabine    Grüner  Level 3 Sales Representative
# 102               103      Parag   Student           Data Analyst Intern
# 103               103      Parag   Student           Data Analyst Intern
#
#             WORK_PHONE  EXTENSION                FAX                 EMAIL  \
# 101  +(43) 13 79 56 32      348.0  +(43) 13 79 56 33   SGruner@grtd123.com
# 102   +31-123-456-7890      123.0   +31-123-456-7891  parag.student@hhs.nl
# 103   +31-123-456-7890      123.0   +31-123-456-7891  parag.student@hhs.nl
#
#               DATE_HIRED  SALES_BRANCH_CODE TRIAL888
# 101  1998-02-18 00:00:00                 39      NaN
# 102           2024-03-24                  1     None
# 103           2024-03-24                  1     None
#
# Nieuwe shape: (104, 11)
# Index van laatste rij: 103
#
# Hulpvraag: welke waarde geef je nu aan axis?
# Antwoord: axis=0, omdat we een rij (verticaal) toevoegen aan het DataFrame.

# %% [markdown]
# ### Kolommen

# %% [markdown]
# Voeg een kolom *FULL_NAME* toe die de waarden van *FIRST_NAME* en *LAST_NAME* achter elkaar zet, gescheiden door een spatie.

# %%
# Voeg een kolom FULL_NAME toe die FIRST_NAME en LAST_NAME combineert met een spatie
sales_staff['FULL_NAME'] = sales_staff['FIRST_NAME'] + ' ' + sales_staff['LAST_NAME']

# Controleer de eerste 5 rijen om te zien dat de kolom is toegevoegd
print("Eerste 5 rijen van sales_staff met FULL_NAME kolom:")
print(sales_staff[['FIRST_NAME', 'LAST_NAME', 'FULL_NAME']].head())
print(f"\nNieuwe shape: {sales_staff.shape}")
print(f"Kolommen: {list(sales_staff.columns)}")
# Out:
# Eerste 5 rijen van sales_staff met FULL_NAME kolom:
#   FIRST_NAME  LAST_NAME          FULL_NAME
# 0      Denis       Pagé         Denis Pagé
# 1  Élizabeth     Michel   Élizabeth Michel
# 2      Émile   Clermont     Émile Clermont
# 3    Étienne     Jauvin     Étienne Jauvin
# 4    Elsbeth  Wiesinger  Elsbeth Wiesinger
#
# Nieuwe shape: (104, 12)
# Kolommen: ['SALES_STAFF_CODE', 'FIRST_NAME', 'LAST_NAME', 'POSITION_EN', 'WORK_PHONE', 'EXTENSION', 'FAX', 'EMAIL', 'DATE_HIRED', 'SALES_BRANCH_CODE', 'TRIAL888', 'FULL_NAME']

# %% [markdown]
# ## Data wijzigen

# %% [markdown]
# ### Datatypen

# %% [markdown]
# Door het attribuut .dtypes van een DataFrame op te vragen krijg je een serie die per kolom het datatype weergeeft. Doe dit bij de originele databasetabel *sales_staff*

# %%
# Toon de datatypes van elke kolom in sales_staff
sales_staff.dtypes
# Out:
# SALES_STAFF_CODE       int64
# FIRST_NAME               str
# LAST_NAME                str
# POSITION_EN              str
# WORK_PHONE               str
# EXTENSION            float64
# FAX                      str
# EMAIL                    str
# DATE_HIRED            object
# SALES_BRANCH_CODE      int64
# TRIAL888              object
# FULL_NAME                str
# dtype: object

# %% [markdown]
# Hier valt op dat elke kolom het datatype 'object' heeft: Python leest dus alles als string. Wiskundige operaties zijn hierdoor niet mogelijk.<br>
# We kunnen proberen om kolommen met getallen, bijvoorbeeld de 'extension', te converteren naar een int. Zie onderstaande code.

# %%
sales_staff['EXTENSION'] = sales_staff['EXTENSION'].astype(int)
sales_staff.dtypes

# %% [markdown]
# Dit lukt echter niet, omdat er in de kolom 'EXTENSION' lege waarden zitten die niet geconverteerd kunnen worden naar een int.<br>
# Wél kan je deze naar een float converteren, zie onderstaande code:

# %%
sales_staff['EXTENSION'] = sales_staff['EXTENSION'].astype(float)
sales_staff.dtypes

# %% [markdown]
# Als we in de rij van 'EXTENSION' kijken zien we dat de conversie van het datatype nu is gelukt.<br>
# Dit is <b>randvoorwaardelijk</b> voor het uitvoeren van wiskundige operaties.<br>

# %% [markdown]
# ### Rijen

# %% [markdown]
# Zorg er nu voor dat bij alle extensions 1 wordt opgeteld.

# %%
# Tel 1 op bij alle extensions
sales_staff['EXTENSION'] = sales_staff['EXTENSION'] + 1

# Controleer de eerste 5 rijen om te zien dat 1 is opgeteld
print("Eerste 5 rijen van EXTENSION kolom na optellen van 1:")
print(sales_staff['EXTENSION'].head())
print(f"\nDatatype van EXTENSION: {sales_staff['EXTENSION'].dtype}")
# Out:
# Eerste 5 rijen van EXTENSION kolom na optellen van 1:
# 0     326.0
# 1     337.0
# 2     379.0
# 3     399.0
# 4    1819.0
# Name: EXTENSION, dtype: float64
#
# Datatype van EXTENSION: float64

# %% [markdown]
# Elke 'Branch Manager' wordt nu 'General Manager'. Schrijf code zodat deze wijziging doorgevoerd wordt in het DataFrame.

# %%
# Vervang 'Branch Manager' door 'General Manager' in POSITION_EN kolom
sales_staff['POSITION_EN'] = sales_staff['POSITION_EN'].replace('Branch Manager', 'General Manager')

# Controleer of de vervanging is gelukt door unieke waarden te tonen
print("Unieke waarden in POSITION_EN kolom na vervanging:")
print(sales_staff['POSITION_EN'].unique())
print(f"\nAantal 'General Manager': {sales_staff['POSITION_EN'].value_counts().get('General Manager', 0)}")
# Out:
# Unieke waarden in POSITION_EN kolom na vervanging:
# <StringArray>
# [             'General Manager', 'Level 3 Sales Representative',
#  'Level 1 Sales Representative', 'Level 2 Sales Representative',
#              'Regional Manager',             'District Manager',
#           'Data Analyst Intern']
# Length: 7, dtype: str
#
# Aantal 'General Manager': 20

# %% [markdown]
# ### Kolommen

# %% [markdown]
# Verander de kolomnaam 'POSITION_EN' naar 'POSITION'.

# %%
# Verander de kolomnaam 'POSITION_EN' naar 'POSITION'
sales_staff = sales_staff.rename(columns={'POSITION_EN': 'POSITION'})

# Controleer of de kolomnaam is gewijzigd
print("Kolommen na hernoeming:")
print(list(sales_staff.columns))
print(f"\nNieuwe kolomnaam 'POSITION' bestaat: {'POSITION' in sales_staff.columns}")
print(f"Oude kolomnaam 'POSITION_EN' bestaat nog: {'POSITION_EN' in sales_staff.columns}")
# Out:
# Kolommen na hernoeming:
# ['SALES_STAFF_CODE', 'FIRST_NAME', 'LAST_NAME', 'POSITION', 'WORK_PHONE', 'EXTENSION', 'FAX', 'EMAIL', 'DATE_HIRED', 'SALES_BRANCH_CODE', 'TRIAL888', 'FULL_NAME']
#
# Nieuwe kolomnaam 'POSITION' bestaat: True
# Oude kolomnaam 'POSITION_EN' bestaat nog: False

# %% [markdown]
# ## Data verwijderen

# %% [markdown]
# ### Rijen

# %% [markdown]
# De medewerkers op indexen 98, 99 en 100 hebben helaas ontslag genomen.<br>
# Verwijder de bijbehorende rijen uit het DataFrame. Gebruik slechts één keer de .drop()-methode.

# %%
# Verwijder de rijen met indexen 98, 99 en 100 (ontslagen genomen)
sales_staff = sales_staff.drop([98, 99, 100])

# Controleer of de rijen zijn verwijderd
print("Shape na verwijdering van rijen:")
print(f"Shape: {sales_staff.shape}")
print(f"Aantal rijen: {len(sales_staff)}")

# Controleer de laatste rijen om te zien dat de indices zijn aangepast
print("\nLaatste 5 rijen van sales_staff:")
print(sales_staff.tail())

# Verificeer dat de verwijderde indices niet meer bestaan
print(f"\nIndex 98 bestaat nog: {98 in sales_staff.index}")
print(f"Index 99 bestaat nog: {99 in sales_staff.index}")
print(f"Index 100 bestaat nog: {100 in sales_staff.index}")
# Out:
# Shape na verwijdering van rijen:
# Shape: (101, 12)
# Aantal rijen: 101
#
# Laatste 5 rijen van sales_staff:
#      SALES_STAFF_CODE FIRST_NAME LAST_NAME                      POSITION  \
# 96                119      Gracy   Gellens               General Manager
# 97                120      Giele  Laermans  Level 1 Sales Representative
# 101               124     Sabine    Grüner  Level 3 Sales Representative
# 102               103      Parag   Student           Data Analyst Intern
# 103               103      Parag   Student           Data Analyst Intern
#
#             WORK_PHONE  EXTENSION                FAX                  EMAIL  \
# 96     +32 16 20.73.21     1350.0    +32 16 20.73.32   GGellens@grtd123.com
# 97     +32 16 20.73.21     1341.0    +32 16 20.73.32  GLaermans@grtd123.com
# 101  +(43) 13 79 56 32      349.0  +(43) 13 79 56 33    SGruner@grtd123.com
# 102   +31-123-456-7890      124.0   +31-123-456-7891   parag.student@hhs.nl
# 103   +31-123-456-7890      124.0   +31-123-456-7891   parag.student@hhs.nl
#
#               DATE_HIRED  SALES_BRANCH_CODE TRIAL888       FULL_NAME
# 96   1999-09-10 00:00:00                 38      NaN   Gracy Gellens
# 97   1999-11-15 00:00:00                 38      NaN  Giele Laermans
# 101  1998-02-18 00:00:00                 39      NaN   Sabine Grüner
# 102           2024-03-24                  1     None   Parag Student
# 103           2024-03-24                  1     None   Parag Student
#
# Index 98 bestaat nog: False
# Index 99 bestaat nog: False
# Index 100 bestaat nog: False

# %% [markdown]
# ### Kolommen

# %% [markdown]
# Faxen zijn inmiddels ouderwets: niemand gebruikt zijn/haar faxnummer nog.<br>
# Verwijder de bijbehorende kolom uit het DataFrame.

# %%
# Verwijder de FAX kolom (ouderwets)
sales_staff = sales_staff.drop('FAX', axis=1)

# Controleer of de kolom is verwijderd
print("Kolommen na verwijdering van FAX:")
print(list(sales_staff.columns))
print(f"\nFAX kolom bestaat nog: {'FAX' in sales_staff.columns}")
print(f"Nieuwe shape: {sales_staff.shape}")

# Toon eerste 5 rijen om te bevestigen dat FAX weg is
print("\nEerste 5 rijen van sales_staff:")
print(sales_staff.head())
# Out:
# Kolommen na verwijdering van FAX:
# ['SALES_STAFF_CODE', 'FIRST_NAME', 'LAST_NAME', 'POSITION', 'WORK_PHONE', 'EXTENSION', 'EMAIL', 'DATE_HIRED', 'SALES_BRANCH_CODE', 'TRIAL888', 'FULL_NAME']
#
# FAX kolom bestaat nog: False
# Nieuwe shape: (101, 11)
#
# Eerste 5 rijen van sales_staff:
#    SALES_STAFF_CODE FIRST_NAME  LAST_NAME                      POSITION  \
# 0                 4      Denis       Pagé               General Manager
# 1                 5  Élizabeth     Michel  Level 3 Sales Representative
# 2                 6      Émile   Clermont  Level 1 Sales Representative
# 3                 7    Étienne     Jauvin  Level 2 Sales Representative
# 4                12    Elsbeth  Wiesinger  Level 2 Sales Representative
#
#           WORK_PHONE  EXTENSION                   EMAIL           DATE_HIRED  \
# 0  +33 1 68 94 52 20      326.0       DPage@grtd123.com  1996-11-03 00:00:00
# 1  +33 1 68 94 52 20      337.0     EMichel@grtd123.com  1995-06-08 00:00:00
# 2  +33 1 68 94 52 20      379.0   EClermont@grtd123.com  1998-04-07 00:00:00
# 3  +33 1 68 94 52 20      399.0     EJauvin@grtd123.com  1997-08-16 00:00:00
# 4  +(49) 40 663 1990     1819.0  EWiesinger@grtd123.com  1997-02-27 00:00:00
#
#    SALES_BRANCH_CODE TRIAL888          FULL_NAME
# 0                  6      NaN         Denis Pagé
# 1                  6      NaN   Élizabeth Michel
# 2                  6      NaN     Émile Clermont
# 3                  6      NaN     Étienne Jauvin
# 4                 13      NaN  Elsbeth Wiesinger
